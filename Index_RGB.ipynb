# %% [markdown]
# # Indices RGB

# %%
from src.utils import index_image_RGB
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./data/0001.jpg')
index = index_image_RGB(img)
cv2.imshow('Original Img',img)
cv2.waitKey(0)
# Out:
# -1

# %%
ExG = index.ExG()
plt.imshow(ExG,cmap='gray')
plt.show()
